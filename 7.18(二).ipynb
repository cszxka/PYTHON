# %% [markdown]
# # 选择
# ## 布尔类型、数值和表达式
# ![](../Photo/33.png)
# - 注意：比较运算符的相等是两个等号，一个等到代表赋值
# - 在Python中可以用整型0来代表False，其他数字来代表True
# - 后面还会讲到 is 在判断语句中的用发

# %%
1<=2<=3
# Out:
# True

# %%
bool('JOKER')
# Out:
# True

# %%
a=id(1)
b=id(1)
#因为a，b并不是一个对象
print(a,b)
a is b
# Out:
# 140710631281472 140710631281472

# %% [markdown]
# ## 字符串的比较使用ASCII值

# %%
a="Jpoker"
b="jpoker"
a>b ci
# Out:
# False

# %%
a="jpoker"
b="jpokar"
a>b
# Out:
# True

# %% [markdown]
# ## Markdown
# - https://github.com/younghz/Markdown

# %% [markdown]
# ## EP:
# - <img src="../Photo/34.png"></img>
# - 输入一个数字，判断其实奇数还是偶数

# %% [markdown]
# ## 产生随机数字
# - 函数random.randint(a,b) 可以用来产生一个a和b之间且包括a和b的随机整数

# %%
import random

# %%
random.randint(0,1)
# Out:
# 1

# %% [markdown]
# 产生一个随机数，你去输入，如果你输入的数大于随机数，那么就告诉你太大了，反之，太小了，
# 然后你一直输入，知道它满意为止

# %%
import random

# %%
for i in range(5):
    input_ = eval(input('输入一个数：'))
    if input_ > number:     
        print('太大啦')
    if input_ < number:   
        print('太小啦')
    if number == input_:
        print('OK')
        break
# Out:
# 输入一个数：1
# 太小啦
# 输入一个数：5
# OK

# %%
for i in range(5):    #执行五次
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for iter_ in xxx:
    do someething

# %%
if condition:       #逢冒号必缩
    do someething
else:
    other

# %%
eval(input('name'))     #转换成数字形式(能运算）中的数字/表达式

# %% [markdown]
# ##  其他random方法
# - random.random 返回0.0到1.0之间前闭后开区间的随机浮点
# - random.randrange(a,b) 前闭后开

# %% [markdown]
# ## EP：
# - 产生两个随机整数number1和number2，然后显示给用户，使用户输入数字的和，并判定其是否正确
# - 进阶:写一个随机序号点名程序

# %%
number_1=random.random(0,10)
number_2=random.random(0,10)
while 1:
    sum_=eval(input('>>'))
    if sum_==(number_1+number_2):
        print('Congratatudshjhtion! correct-')
    else:
        print('sorry-s')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-0a597211cab6> in <module>
# ----> 1 number_1=random.random(0,10)
#       2 number_2=random.random(0,10)
#       3
#       4 while 1:
#       5     sum_=eval(input('<<'))
#
# TypeError: random() takes no arguments (2 given)

# %% [markdown]
# ## if语句
# - 如果条件正确就执行一个单向if语句，亦即当条件为真的时候才执行if内部的语句
# - Python有很多选择语句:
# > - 单向if
#   - 双向if-else
#   - 嵌套if
#   - 多向if-elif-else
#
# - 注意：当语句含有子语句的时候，那么一定至少要有一个缩进，也就是说如果有儿子存在，那么一定要缩进
# - 切记不可tab键和space混用，单用tab 或者 space
# - 当你输出的结果是无论if是否为真时都需要显示时，语句应该与if对齐

# %%
input_ = eval(input('输入姓名：'))
number
if number==(number_1+number_2):
        print('Congratatudshjhtion! correct-')
    else:
        print('sorry-s')

# %%
age = input('年轻嘛[y/n]')
if age == 'y':
    handsome = input('帅否[y/n]')
    if handsome == 'y':
        wife = input('有没有老婆[y/n]')
        if wife == 'y':
            print('回家的诱惑')
        else: 
            print('立马结婚')
    else: 
        print('考虑一下')
else:
    print('拜拜')

# %%
age = input('年轻嘛[y/n]')
if age == 'y':
    handsome = input('帅否[y/n]')
    if handsome == 'y':
        wife = input('有没有老婆[y/n]')
        if wife == 'y':
            print('回家的诱惑')
        else:
            print('立马结婚')
    else:
        print('考虑一下')
else:
    print('拜拜')

# %% [markdown]
# ## EP：
# - 用户输入一个数字，判断其实奇数还是偶数
# - 进阶：可以查看下4.5实例研究猜生日

# %% [markdown]
# ## 双向if-else 语句
# - 如果条件为真，那么走if内部语句，否则走else内部语句

# %% [markdown]
# ## EP：
# - 产生两个随机整数number1和number2，然后显示给用户，使用户输入数字，并判定其是否正确,如果正确打印“you‘re correct”，否则打印正确错误

# %% [markdown]
# ## 嵌套if 和多向if-elif-else
# ![](../Photo/35.png)

# %% [markdown]
# ## EP：
# - 提示用户输入一个年份，然后显示表示这一年的动物
# ![](../Photo/36.png)
# - 计算身体质量指数的程序
# - BMI = 以千克为单位的体重除以以米为单位的身高的平方
# ![](../Photo/37.png)

# %%
year = eval(input("年份"))
if year % 12 ==0:
    res="🐵"
elif year %12== 1 :
    res="🐦"
elif year %12== 2 :
    res="🐶"
elif year %12== 3  :
    res="🐖"
elif year %12== 4 :
    res="🐭"
elif year %12== 5 :
    res="🐮"
elif year %12== 6 :
    res="😼"
elif year %12== 7 :
    res="🐇"
elif year %12== 8 :
    res="🐉"
elif year %12== 9 :
    res="🐍"
elif year %12== 10 :
    res="🐎"
elif year %12== 11 :
    res="🐏"
print(res)
# Out:
# 年份1998
# 😼

# %%
tizhong = float(input('请输入体重'))
shengao = float(input('请输入身高'))
BMI=tizhong / shengao ** 2 
if BMI<18.5:
    print('超清')
elif 18.5<=BMI<25.0:
    print('标准')
elif 25.0<=BMI<30.0:
    print('超重')
else :
    print('巨重')
# Out:
# 请输入体重67
# 请输入身高1.67
# 标准

# %% [markdown]
# ## 逻辑运算符
# ![](../Photo/38.png)

# %% [markdown]
# ![](../Photo/39.png)
# ![](../Photo/40.png)

# %% [markdown]
# ## EP：
# - 判定闰年：一个年份如果能被4整除但不能被100整除，或者能被400整除，那么这个年份就是闰年
# - 提示用户输入一个年份，并返回是否是闰年
# - 提示用户输入一个数字，判断其是否为水仙花数

# %%
year=eval(input('Year'))

if(year%4==0 and year% 100 !=0)or(year%400==0):
    print('闰年')
else:
    print('平年')
# Out:
# Year1998
# 平年

# %%
Number=eval(input('>>'))

bai=Number // 100
shi=Number//10%10
ge=Number%10

if bai**3+shi**3+ge**3==Number:
    print('水仙花')
else:
    print('不是水仙花')
# Out:
# >>223
# 不是水仙花

# %% [markdown]
# ## 实例研究：彩票
# ![](../Photo/41.png)

# %%
import random

# %%
number=random.randint(10,99)
print(number)
N=eval(input('>>'))
number_shi=number//10
number_ge=number%10
if N[0]=='0':
    N_shi=0
else:
    N_shi=N//10
    N_ge=N%10

if number==N:
    print('10000')
elif number_shi+number_ge==N_shi+N_ge:
    print('3000')
elif(number_ge==N_ge or number_ge==N_shi) or (number_shi==N_ge or number_shi==N_shi):
    print('1000')
# Out:
# 17
# >>70
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-75aec84c478b> in <module>
#       4 number_shi=number//10
#       5 number_ge=number%10
# ----> 6 if N[0]=='0':
#       7     N_shi=0
#       8 else:
#
# TypeError: 'int' object is not subscriptable

# %%
a='Joker'
a[0]
# Out:
# 'J'

# %% [markdown]
# # Homework
# - 1
# ![](../Photo/42.png)

# %%
import math
a = eval(input("a为："))
b = eval(input("b为："))
c = eval(input("c为："))
X1 = b**2-4*a*c
if X1>0:
    r1 = (-b+math.sqrt(b**2-4*a*c))/(2*a)
    r2 = (-b-math.sqrt(b**2-4*a*c))/(2*a)
    print(r1,r2)
if X1==0:
    r=-b/2*a
    print(r)
if X1<0:
    print('The equation has no real roots')
# Out:
# a为：1
# b为：2
# c为：3
# The equation has no real roots

# %% [markdown]
# - 2
# ![](../Photo/43.png)

# %%
import random
value1 = random.randint(0,99)
value2 = random.randint(0,99)
sum1 = value1+value2
sum = eval(input("输入这两个整数的和"))
if sum == sum1:
    print("程序报告结果为真")
else:
    print("程序报告为假")
print("这两个随机数为：",value1,value2)
# Out:
# 输入这两个整数的和234
# 程序报告为假
# 这两个随机数为： 93 14

# %% [markdown]
# - 3
# ![](../Photo/44.png)

# %%
today = eval(input("输入今天是一周的某一天:"))
num = eval(input("输入今天之后到未来某天的天数:"))
if num%7==0:
    laterday = "Sunday"
elif num%7==1:
    laterday = "Monday"
elif num%7==2:
    laterday = "Tuesday"
elif num%7==3:
    laterday = "Wednesday"
elif num%7==4:
    laterday = "Thursday"
elif num%7==5:
    laterday = "Friday"
elif num%7==6:
    laterday = "Saturday"
print("今天是：",today)
print("未来是：",laterday)
# Out:
# 输入今天是一周的某一天:2
# 输入今天之后到未来某天的天数:7
# 今天是： 2
# 未来是： Sunday

# %% [markdown]
# - 4
# ![](../Photo/45.png)

# %%
num1 = int(input("请输入整数："))
num2 = int(input("请输入整数："))
num3 = int(input("请输入整数："))
num = [num1,num2,num3]
num.sort( )
print(sum)z
# Out:
#   File "<ipython-input-4-9b756cc0e50b>", line 6
#     print(sum)z
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# - 5
# ![](../Photo/46.png)

# %%
x = int(input('请输入第一个整数：'))
y = int(input('请输入第二个整数：'))
z = int(input('请输入第三个整数：'))
if x>y:
    x,y = y,x
if x>z:
    x,z = z,x
if y>z:
    y,z = z,y
print(x,y,z)
# Out:
# 请输入第一个整数：12
# 请输入第二个整数：34
# 请输入第三个整数：57
# 12 34 57

# %% [markdown]
# - 6
# ![](../Photo/47.png)

# %%
month,year=eval(input('输入年月:'))
run=year % 4
if month==1 or month == 3 or

# %% [markdown]
# - 7
# ![](../Photo/48.png)

# %%
Cai = eval(input("输入猜测值正确与否[1/0]"))
if Cai ==1:
    print("猜测正确")
else:
    print("猜测错误")
# Out:
# 输入猜测值正确与否[1/0]1
# 猜测正确

# %% [markdown]
# - 8
# ![](../Photo/49.png)

# %% [markdown]
# - 9
# ![](../Photo/50.png)

# %% [markdown]
# - 10
# ![](../Photo/51.png)

# %%
daxiao=random.randint(1,13)
huase=random.randint(1,4)
if daxiao==1:
    daxiao='A'
elif daxiao==2:
    daxiao='B'
elif daxiao==3:
    daxiao='C'
elif daxiao==4:
    daxiao='D'
elif daxiao==5:
     daxiao='E'
elif daxiao==6:
     daxiao='F'
elif daxiao==11:
    daxiao='J'
elif daxiao==12:
    daxiao='Q'
elif daxiao==13:
    daxiao='K'
if huase==1:
    huase='梅花'
elif huase==2:
    huase='红桃'
elif huase==3:
    huase='方块'
elif huase==4:
    huase='黑桃'
print(huase,daxiao,sep='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-655aadc75856> in <module>
# ----> 1 daxiao=random.randint(1,13)
#       2 huase=random.randint(1,4)
#       3 if daxiao==1:
#       4     daxiao='A'
#       5 elif daxiao==11:
#
# NameError: name 'random' is not defined

# %% [markdown]
# - 11
# ![](../Photo/52.png)

# %%
num=input('请输入一个整数:')
num1=num[::-1]
if num==num1:
    print(num,'is a palindrome')
else:
    print(num,'is not a palindrome')
# Out:
# 请输入一个整数:123
# 123 is not a palindrome

# %% [markdown]
# - 12
# ![](../Photo/53.png)

# %%
a,b,c=eval(input('请输入三角形三边长:'))
if (a+b)>c and (a+c)>b and (b+c)>a:
    zhouchang=a+b+c
    print(zhouchang)
else:
    print('不是三角形')
# Out:
# 请输入三角形三边长:1,1,1
# 3
